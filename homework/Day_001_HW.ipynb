# %% [markdown]
# 作業1
# Titanic: Machine Learning from Disaster
# Q1 你選的這組資料為何重要
# 	好玩
# Q2 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 	Kaggle提供
# Q3 蒐集而來的資料型態為何
# 	string int
# Q4 這組資料想解決的問題如何評估
# 	對於生還者預測的正確率

# %% [markdown]
# 作業2
# Q1 核心問題為何
# 	提升業績: 視為提升NetSales, 即保證成本上升的幅度小於營業狀況下, 最大提高營業收入
# 		成本: 空車時間, 汽油費*行駛距離, 尋客成本(從現在位置至載客地點)
# 		營業收入: 底價 + 里程單位價格 * max(0, (行駛距離-底價距離))
# 		業績指標: 營業收入 / 成本
# 	環境假設:
# 		當今環境, 因成本高(空車時間過長, 尋客成本高), 或因營業收入(載客頻率低)等問題, 需要提升業績
#
# Q2  資料從何而來
# 	資料變數: 人口作息分布, 人口聚集分布, 即時交通路況, 交通流量圖, 載客需求頻率發生表
# 	資料取得: 交通部, 田野調查, 計程車公會
#
# Q3 蒐集而來的資料型態為何
# 	結構話: string, int
# 	非結構話: 各式分布圖
#
# Q4 你要回答的問題，其如何評估
# 	其業績指標是否能顯著成長

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.773

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 219.794
# The Mean absolute error is 11.773
